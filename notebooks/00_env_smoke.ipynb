# %%
# ABOUTME: Environment sanity checks for smol-llm dev work.
# ABOUTME: Verifies Python, torch, and CUDA visibility.

# %% [markdown]
# # environment smoke test
#
# run this after setting up the `uv` environment to confirm torch and cuda.

# %%
print("hello world")
# Out:
# hello world

# %%
import sys
import torch

print("python", sys.version)
print("torch", torch.__version__)
print("cuda_available", torch.cuda.is_available())
if torch.cuda.is_available():
    print("cuda_name", torch.cuda.get_device_name(0))
# Out:
# python 3.13.11 (main, Dec  7 2025, 13:01:45) [GCC 15.2.1 20251112]
# torch 2.9.1+cu128
# cuda_available True
# cuda_name NVIDIA GeForce RTX 3060
